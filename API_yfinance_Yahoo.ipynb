# %%
import yfinance as yf

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt
from datetime import datetime
plt.style.use('seaborn')

# %%
msft=yf.Ticker('msft')

# %%
print(msft.info)
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-33-bf7917b711e5> in <module>
# ----> 1 print(msft.info)
#
# ~\anaconda3\lib\site-packages\yfinance\ticker.py in info(self)
#     136     @property
#     137     def info(self) -> dict:
# --> 138         return self.get_info()
#     139
#     140     @property
#
# ~\anaconda3\lib\site-packages\yfinance\base.py in get_info(self, proxy)
#    1473     def get_info(self, proxy=None) -> dict:
#    1474         self._quote.proxy = proxy
# -> 1475         data = self._quote.info
#    1476         return data
#    1477
#
# ~\anaconda3\lib\site-packages\yfinance\scrapers\quote.py in info(self)
#      93     def info(self) -> dict:
#      94         if self._info is None:
# ---> 95             self._scrape(self.proxy)
#      96             self._scrape_complementary(self.proxy)
#      97
#
# ...

# %%
msft.history()
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2023-01-25 00:00:00-05:00  233.894161  242.692132  230.323103  240.008850
# 2023-01-26 00:00:00-05:00  243.041248  247.689609  241.395377  247.380386
# 2023-01-27 00:00:00-05:00  248.367921  249.205819  246.213314  247.539993
# 2023-01-30 00:00:00-05:00  243.899098  244.986386  241.594872  242.103607
# 2023-01-31 00:00:00-05:00  242.841750  247.330507  242.342999  247.190857
# 2023-02-01 00:00:00-05:00  247.380383  254.542436  244.856705  252.118515
# 2023-02-02 00:00:00-05:00  258.173346  264.028675  256.607262  263.938904
# 2023-02-03 00:00:00-05:00  258.891558  263.539919  256.457652  257.704529
# 2023-02-06 00:00:00-05:00  256.796788  257.654625  254.143430  256.128448
# 2023-02-07 00:00:00-05:00  259.879075  268.098478  259.430188  266.891510
# 2023-02-08 00:00:00-05:00  272.517435  276.068538  265.544878  266.063599
# 2023-02-09 00:00:00-05:00  273.115924  273.295497  262.143406  262.961365
# ...

# %%
print(msft.dividends)
# Out:
# Date
# 2003-02-19 00:00:00-05:00    0.08
# 2003-10-15 00:00:00-04:00    0.16
# 2004-08-23 00:00:00-04:00    0.08
# 2004-11-15 00:00:00-05:00    3.08
# 2005-02-15 00:00:00-05:00    0.08
#                              ...
# 2022-02-16 00:00:00-05:00    0.62
# 2022-05-18 00:00:00-04:00    0.62
# 2022-08-17 00:00:00-04:00    0.62
# 2022-11-16 00:00:00-05:00    0.68
# 2023-02-15 00:00:00-05:00    0.68
# Name: Dividends, Length: 77, dtype: float64

# %%
print(msft)
# Out:
# yfinance.Ticker object <MSFT>

# %%
df=msft.dividends

# %%
print(type(df))
# Out:
# <class 'pandas.core.series.Series'>

# %%
print(df)
# Out:
# Date
# 2003-02-19 00:00:00-05:00    0.08
# 2003-10-15 00:00:00-04:00    0.16
# 2004-08-23 00:00:00-04:00    0.08
# 2004-11-15 00:00:00-05:00    3.08
# 2005-02-15 00:00:00-05:00    0.08
#                              ...
# 2022-02-16 00:00:00-05:00    0.62
# 2022-05-18 00:00:00-04:00    0.62
# 2022-08-17 00:00:00-04:00    0.62
# 2022-11-16 00:00:00-05:00    0.68
# 2023-02-15 00:00:00-05:00    0.68
# Name: Dividends, Length: 77, dtype: float64

# %%
data=df.resample('Y').sum()

# %%
data=data.reset_index()

# %%
data['Year']=data['Date'].dt.year

# %%
plt.figure()
plt.bar(data['Year'],data['Dividends'])
plt.ylabel('Dividend Yield ($)')
plt.xlabel('Year')
plt.title('Microsoft Dividend history')
plt.xlim(2002,2023)
plt.show()

# %%
print(msft.cashflow)
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-57-38db1abf4821> in <module>
# ----> 1 print(msft.cashflow)
#
# ~\anaconda3\lib\site-packages\yfinance\ticker.py in cashflow(self)
#     204     @property
#     205     def cashflow(self) -> _pd.DataFrame:
# --> 206         return self.cash_flow
#     207
#     208     @property
#
# ~\anaconda3\lib\site-packages\yfinance\ticker.py in cash_flow(self)
#     196     @property
#     197     def cash_flow(self) -> _pd.DataFrame:
# --> 198         return self.get_cash_flow(pretty=True, freq="yearly")
#     199
#     200     @property
#
# ~\anaconda3\lib\site-packages\yfinance\base.py in get_cash_flow(self, proxy, as_dict, pretty, freq, legacy)
#    1655             data = self._fundamentals.financials.get_cash_flow_scrape(freq=freq, proxy=proxy)
#    1656         else:
# ...

# %%
print(msft.financials)
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-58-22696b5fc5ae> in <module>
# ----> 1 print(msft.financials)
#
# ~\anaconda3\lib\site-packages\yfinance\ticker.py in financials(self)
#     172     @property
#     173     def financials(self) -> _pd.DataFrame:
# --> 174         return self.income_stmt
#     175
#     176     @property
#
# ~\anaconda3\lib\site-packages\yfinance\ticker.py in income_stmt(self)
#     156     @property
#     157     def income_stmt(self) -> _pd.DataFrame:
# --> 158         return self.get_income_stmt(pretty=True)
#     159
#     160     @property
#
# ~\anaconda3\lib\site-packages\yfinance\base.py in get_income_stmt(self, proxy, as_dict, pretty, freq, legacy)
#    1580             data = self._fundamentals.financials.get_income_scrape(freq=freq, proxy=proxy)
#    1581         else:
# ...

# %%
print(msft.balance_sheet)
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-59-74039faee5fe> in <module>
# ----> 1 print(msft.balance_sheet)
#
# ~\anaconda3\lib\site-packages\yfinance\ticker.py in balance_sheet(self)
#     180     @property
#     181     def balance_sheet(self) -> _pd.DataFrame:
# --> 182         return self.get_balance_sheet(pretty=True)
#     183
#     184     @property
#
# ~\anaconda3\lib\site-packages\yfinance\base.py in get_balance_sheet(self, proxy, as_dict, pretty, freq, legacy)
#    1619             data = self._fundamentals.financials.get_balance_sheet_scrape(freq=freq, proxy=proxy)
#    1620         else:
# -> 1621             data = self._fundamentals.financials.get_balance_sheet_time_series(freq=freq, proxy=proxy)
#    1622
#    1623         if pretty:
#
# ...

# %%
print(msft.history(period='max'))
# Out:
#                                  Open        High         Low       Close  \
# Date
# 1986-03-13 00:00:00-05:00    0.055241    0.063365    0.055241    0.060657
# 1986-03-14 00:00:00-05:00    0.060657    0.063907    0.060657    0.062823
# 1986-03-17 00:00:00-05:00    0.062823    0.064448    0.062823    0.063907
# 1986-03-18 00:00:00-05:00    0.063907    0.064448    0.061740    0.062281
# 1986-03-19 00:00:00-05:00    0.062281    0.062823    0.060657    0.061198
# ...                               ...         ...         ...         ...
# 2023-02-17 00:00:00-05:00  259.390015  260.089996  256.000000  258.059998
# 2023-02-21 00:00:00-05:00  254.479996  255.490005  251.589996  252.669998
# 2023-02-22 00:00:00-05:00  254.089996  254.339996  250.339996  251.509995
# 2023-02-23 00:00:00-05:00  255.559998  256.839996  250.479996  254.770004
# 2023-02-24 00:00:00-05:00  249.960007  251.000000  248.100006  249.220001
#
#                                Volume  Dividends  Stock Splits
# Date
# ...

# %%
print(type(msft.history(period='max')))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
df=msft.history(period='max')

# %%
plt.figure()
plt.plot(df['Close'])
plt.show()

# %%
df=msft.history(start='2007-01-01',end='2023-02-25')
plt.figure()
plt.plot(df['Close'])
plt.show()

# %%
df=msft.history(start='2007-01-01',end='2023-02-25')
plt.figure()
plt.plot(df['Open'])
plt.show()

# %%
df=msft.history(start='2007-01-01',end='2023-02-25')
plt.figure()
plt.plot(df['High'])
plt.show()

# %%
security=yf.Ticker('voo')

# %%
df=security.history(start='2007-01-01',end='2023-02-25')
plt.figure()
plt.plot(df['Close'])
plt.show()

# %%
security=yf.Ticker('djia') #Dow Jones Industrial Average

# %%
df=security.history(start='2007-01-01',end='2023-02-25')
plt.figure()
plt.plot(df['Close'])
plt.show()

# %%
security=yf.Ticker('voo')

# %%
today=datetime.now().date().strftime("%Y-%m-%d")

# %%
df=security.history(start='2007-01-01',end=today)
plt.figure()
plt.plot(df['Close'])
plt.show()

# %%
securities=['voo','msft','aapl','tsla','nvda','jnj','axp','dis','wmt']

# %%
df=pd.DataFrame()

# %%
today=datetime.now().date().strftime("%Y-%m-%d")

# %%
for security in securities:
    df[security]=yf.Ticker(security).history(start='2007-01-01',end=today).Close

# %%
plt.figure()
plt.plot(df)
plt.ylabel('Price ($)')
plt.xlabel('Year')
plt.show()
plt.legend(loc="upper left")
# Out:
# No handles with labels found to put in legend.
